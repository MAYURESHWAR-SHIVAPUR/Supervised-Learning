# %% [markdown]
# ---
# ---
#
# <h1 style="color:#00FFFF"><b> Xgboost</b></h1>
#
# ---
# ---
#
# ## **Defination**
#
# `It is an ensmble technique which uses multiple decission tree. which is used for both regression and classification`
#
# `We use boosting when decision tree becomes under fit`
#
# `It reduces the baise`
#
# `Sequency it passes all 100 trees`
#
# ---
#
# ## **What**
#
# `Xgboost stands for` `Extream gradient boosting algorithum`
#
# `Which comes under boosting ensemble technique`
#
# ---
#
#
# ## **Technique which is used internally**
#
# `Regrularization`
# `Gradientation`
#
# ---
#
#
# ## **Advantages of XGBoost**
#
# `Scaling techniques not required`
#
# `It handles missing values`
#
# `It handles categorical columns`
#
# `It works well with large dataset`
#
# `It handles both HIGH VARIENCE and HIGH BAISE`
#
# `Pre-processing techniques not needed but need for sentence based feature col`
#
# `Trees are indepentent`
#
# `formula` `1/(1+(e**-z))`
#
# `formula` `wz = w1 X1 + w2 + x2 + c`
#
# `Reducing baise but this is high level model it can reduce varience as it uses internally regulaiztion`
#
#
#
#
# ## **Working**
#
# `It correct the mistakes of previous models so these are called weak learners`
#
#
#
# ---
# ---
#
# # **Important for interviews**
#
# ---
# ---
#
# `In interview explan with unique points not with are commonnly said`
#
# bagging|boosting
# ---|---
# parallel exceutes | Sequency execustes
# reduces varience| baise
# random samples  | entire samples
# random forest |adptaing bossting, lite gbm boosting, best is Xgboost
# small or medium dataset | large dataset
#
# <br/>
#
# Random forest Classifier | Xgboost Classifier
# ---|---
# bagging alg | boosting alg
# executes parallel  | sequentily
# trees are indepent | Trees are depentet
# assing saples randomly | Takes entire sample
# during predication take majority | it calculates weights and use sigmoib func for output
# reduces variences | reduces bais
# small to medium dataset | large dataset
# it dont use regulaztion and grandation | use regulaztion and grandation
# it dont handle missing vaues | hadles missing values
# it is present in sklearn | it is present in xgboost
#
# <br/>
#
# ---
# ---
