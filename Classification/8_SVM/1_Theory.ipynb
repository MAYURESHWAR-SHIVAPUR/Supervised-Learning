# %% [markdown]
# ---
# ---
#
# <h1 style="color:#00FFFF"><b>SVM (Support vector Machine)</b></h1>
#
# ---
# ---
#
# ## **Defination**
#
# `It is a supervised learning algorithum which is used for both regression and classification scenarios but mostly we use this for CLASSIFICATION `
#
# `When number of features are greater than number samples then we use SVM. IN real time we use this for image based classification (we get high dimensions)`
#
# `SVR (support vector Regression)` `SVC (support vector classifier)`
