# %% [markdown]
# ---
# ---
#
# <h1 style="color:#00FFFF"><b> Logistic Regression</b></h1>
#
# ---
# ---
#
# ### **Defination**
#
# > it is a supervised learning algroithum which comes under regression and used for classification scenario
# ---
#
# ### **Classification Algorithum**
# > it is a supervised learning technique which predicts categorical values
#
# ---
#
# ### **Example**
#
# <h4 style="color:orange"><b>Spam Detection:=> </b> Here classification will predict scam or not scam</h4>
#
# <h4 style="color:orange"><b>Sentamental Analysis:=> </b> Here classification will predict positive, negative and nutral</h4>
#
# ---
#
# ### **How to select Algorithums**
# > if target column values are continous then Regression Algorithum
#
# > if target column values are categorical then Classification Algorithum
#
# ---
#
# ### **Why under Regression**
# > internally it uses Regression Formula = (w1 x1) + (w2 x2) + c
#
# ---
#
# <h4 style="color:orange"><b>Note :=> </b>Polynomial features is not a algorithum and formula is applied in Linear Regression not in polynomial</h4>
#
# ---
#
# ### **Logistic**
#
# > it uses sigmoid funtion (it classifys binary value [0,1])
#
# > formula p =     1 /(1 + e)
#
# > Graph shape :  S
#
# > base threshold is 0.5 and if x < 0.5 = 0; x > 0.5 = 1
#
# ---
#
# ### **Why not Linear Regression**
#
# > linear Graph shape /
#
# > it will not give fixed range like 0 or 1
#
# > it follow onl straigt line so values are not fixed can be -3 or 50 or 5
#
# ---
#
# ### **How weights are calculaing in Logistic Regression**
#
# > 1. first Randmonly it initialzes the weights between 0 and 0.5
#
# > 2. Later which the help of gradient descent it finds the best weights
#
# > 3. To find or Optimise the best weights internally it takes multiple iterations
#
# ---
#
# ### **Techniques used by logistic Regression Internally**
#
# > 1. Lost Function
#
# > 2. Cost Function
#
# > 3. Sigmoid Function
#
# > 4. Regurallization Techniques (l1,l2,elastic net)
#
# > 5. Gradient Descent
#
# ---
#
# <h3 style="color:orange"><b>Internally Working of Logistic Regression</b></h3>
#
# #### **1. Loss Function**
#
# > internally used by Logistic Regression
#
# > it measures error per Record
#
# #### **2. Cost Function**
#
# > it is also used by Logistic Internally
#
# > It measures over all model Mistakes (Error)
#
# > this will use log_loss() => internally
#
# #### **3. Sigmoid Function**
#
# > get get binary values
#
# ---
#
# #### **4. Regularization**
#
# > it is a ML techique which help use to reduce the varience with the help of penalties (l1,l2,elastic net)
#
# > **l1 --> Losso | l2 --> Ridge | elastient --> l1 + l2** ===> these are panalties given when error is caused
#
# > this all are used at the model traning only (inside fit)
#
# #### **4.1. when to use l1(Lasso)**
#
# > it is a regularition penailty which selects important features by pussing the weights towards to 0 and excatly to 0
#
# > if the weight is zero which means that feature is not important
#
# ```
# ex = | m1 = 0 | c = 10 | m2 = 5 | x1 = 5 | x2 = 6 |
#         m1*x1+ m2 * x2 + c
#         0 * 5 + 5 * 6 + 10 = 40
# ```
#
# > when we have more features
#
# > for sentace based classifiction
#
# > when we dont know the important features
# #### **4.2. when to use l2(Ridge)**
#
# > we use l2 when all features are important or when multi co-linearity occurs
#
# > it is a regulalariztion penalty which keeps all the columns by strinking the weights
#
# > it strinks the weights but never forces to 0
#
# > **When to use the Ridge**
#
# > when all the feature columns are important
#
# > when multi co-linearty problem occurs
#
# #### **4.3. when to use Elastient**
#
# > it is a regularization penalty which uses both l1 and l2
#
# > it selects important features and also handles multi co-linearty problem
#
# ---
#
# ### **5. Gradintation**
#
# > it is an optimization technique which is used to find the best weights
#
# > How well the model captures the pattern of unseen data
#
# > if the model captures the pattern of unseen data then the model is generalized well
#
# > if the model captures the unseen data pattern then the model is not generalized well (OVERFIT)
#
# > Solution :=> Regularization
#
# > **where we use grandation in Machine Learning**
#
# > Logistic Regression Internally uese grantation to find the best weights
#
# > Extream gradient boosting algorithum(Xgboost) uses grandation to find the best weights
#
# > Regularization techniques uses the grantation to find a best weights and reduce the varience.
