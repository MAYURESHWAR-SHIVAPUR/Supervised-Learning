# %% [markdown]
# ---
# ---
#
# <h1 style="color:#00FFFF"><b>Grid Search CV (Cross validation)</b></h1>
#
# ---
# ---
#
# ## **Defination**
#
# `It is hyper parameter tuning technique which balances both baise and varience by selecting the best parameter values`
#
# ---
#
# ## **Imports**
#
# `from sklearn.model_selection import GridSearchCV`
#
# gridSearchcv = GridSearchCV(
#     estimator=DecisionTreeClassifier() | pipeline,
#     cv = 3 | 5 | 10 | int(),
#     param_grid = {
#         "parameter_name":[values1, values2, values3],
#         "parameter_name":[values1, values2, values3],
#         "parameter_name":[values1, values2, values3],
#     } | dic,
#     n_jobs = 1, 2, 3, ... | int(),
#     verbose = 0, 1, 2, 3, ... |int(),
#     score = "r2" | "f1" | "accuracy"
#
# )
#
# ---
#
# ## **Scenario-1**
#
# `Syntax for GridSearchCV without pipline`
#
# gird_search_cv = GridSearchCV(
#     estimator = DecissionTreeClassifier(),
#     param_grid = {
#         "max_depth":[None, 10, 50, 100]
#     }
#
#     cv = 5
# )
#
# ---
#
# ## **Scenario-2**
#
# `Syntax for GridSearchCV with pipline`
#
# pipline = Pipline(
#     steps=[
#
#         ("pre": preprossing),
#
#         ("model": DecissionTreeClassifier())
#
#     ]
# )
#
# gird_search_cv = GridSearchCV(
#
#     estimator = pipline,
#     param_grid = {
#         "model__max_depth":[None, 10, 50, 100]
#     }
#
#     cv = 5
# )
#
# `5 -folds (equal 5 splits)`
#
# fold_1 = 2
# fold_2 = 2
# fold_3 = 2
# fold_4 = 2
# fold_5 = 2
#
# train | test
# ---|---
# cv1= F1, F2, F3, F4|F5
# cv1= F1, F5, F3, F4|F2
# cv1= F1, F2, F5, F4|F3
# cv1= F1, F2, F3, F5|F4
# cv1= F5, F2, F3, F5|F1
#
#
# `None, gini`
#
# --> cv1 = 90%
#
# --> cv2 = 80%
#
# --> cv3 = 75%
#
# --> cv4 = 70%
#
# --> cv5 = 90%
#
# --> avg = 81%
#
# `None, entropy`
#
# --> avg = 87%
#
# `10, gini`
#
# --> avg = 95%
#
# `and so on`
